# %%
push!(LOAD_PATH, pwd());
using TSSM
# Out:
#  *** OPENMP n_threads =           8

# %%
V(x) = x^2
m = SchroedingerReal1D(2048, -30, 30, potential=V, cubic_coupling=390)
# Out:
# TSSM.SchroedingerReal1D(Ptr{Void} @0x000000000313a6d0)

# %%
psi=wave_function(m)
# Out:
# TSSM.WfSchroedingerReal1D(Ptr{Void} @0x0000000003163ec0,TSSM.SchroedingerReal1D(Ptr{Void} @0x000000000313a6d0))

# %%
f(x)=exp(-x^2)
set!(psi, f)

# %%
include("groundstate.jl")
# Out:
# groundstate! (generic function with 1 method)

# %%
groundstate!(psi, extrapolation_order=2)
# Out:
# 1.537672426174445
#     0   4.122241185249612e+01   7.425985542158324e+01   1.000e+06   5.555e-01   1.040e+01      0.01   2.850224319596682e+01   1.000e+06   3.292e-01
# changed step size, old:   5.000000000000000e-02  new:   2.500000000000000e-02
#     1   2.688007443967734e+01   4.313509833994344e+01   1.434e+01   1.212e-01   1.441e-01      0.01
#     2   2.707612519037942e+01   4.457455820968354e+01  -1.961e-01   2.659e-01   8.340e-02      0.01
#     3   2.848381050720726e+01   4.747971339697094e+01  -1.408e+00   5.564e-01   8.634e-02      0.01
#     4   2.866049653246653e+01   4.786645717074038e+01  -1.767e-01   6.221e-01   5.081e-02      0.01
#     5   2.848003438264342e+01   4.737877650693188e+01   1.805e-01   6.047e-01   3.220e-02      0.02
#     6   2.814462839605272e+01   4.675465367599473e+01   3.354e-01   5.613e-01   2.121e-02      0.02
#     7   2.800868455468703e+01   4.647152997479280e+01   1.359e-01   5.392e-01   1.420e-02      0.02
# ...

# %%
using PyPlot

# %%
x=get_nodes(m);
u=get_data(psi,true)
to_real_space!(psi)
plot(x, u[1:end-2].^2)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8aee835d10>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f8aee46ba90>
